# %%
! /opt/bin/nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
! cd /content/drive/MyDrive/PlayTermuxLogo && ls

# %%
! apt update -y
! apt upgrade -y
! apt install git wget -y
! apt autoremove -y
! apt clean all -y

# %%
! rm -rfv Blender

# %%
! mkdir Blender

# %%
! cd Blender && wget https://download.blender.org/release/Blender3.3/blender-3.3.0-linux-x64.tar.xz -O Blender.tar.xz

# %%
! cd Blender && tar xfv Blender.tar.xz

# %%
! rm -rfv ./Blender/Blender.tar.xz

# %%
! git clone https://github.com/FurryRbl/PlayTermuxLogo.git

# %%
! ls ./PlayTermuxLogo/

# %%
! ./Blender/blender-3.3.0-linux-x64/blender -b /content/drive/MyDrive/PlayTermuxLogo/Logo.blend -o /content/drive/MyDrive/PlayTermuxLogo/out/ -f 0 --cycles-device OPTIX +CUDA +CPU --cycles-print-stats -F PNG -noaudio -E CYCLES

# %%
! ./Blender/blender-3.3.0-linux-x64/blender -b ./PlayTermuxLogo/Logo.blend -o /content/drive/MyDrive/Blender/out/ -f 0 --cycles-device OPTIX +CUDA +CPU --cycles-print-stats -F PNG -noaudio -E CYCLES
